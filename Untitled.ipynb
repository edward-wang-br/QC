# %%
from qiskit import __version__

print(__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_54086/1207793948.py in <cell line: 1>()
# ----> 1 from qiskit import __version__
#       2
#       3 print(__version__)
#
# ~/QC/qiskit.py in <module>
#       1 import numpy as np
# ----> 2 from qiskit.visualization import array_to_latex
#       3
#       4 ket0 = np.array([[1], [0]])
#       5 ket1 = np.array([[0], [1]])
#
# ModuleNotFoundError: No module named 'qiskit.visualization'; 'qiskit' is not a package
